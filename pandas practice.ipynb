# %%
import pandas as pd

# %%
df = pd.read_csv("/content/movies.csv")

# %%
df.head(5)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
df.columns = [i.lower() for i in df]

# %%
df = df.replace(r'\n',' ', regex=True)

# %%
df["year"]=df["year"].str.strip("()")

# %%
df.head(1)
# Out:
#         movies  year                 genre  rating  \
# 0  BloodRedSky  2021  ActionHorrorThriller     6.1
#
#                                             one-line  \
# 0   A woman with a mysterious illness is forced i...
#
#                                                stars   votes  runtime gross
# 0       Director: Peter Thorwarth |      Stars: P...  21,062    121.0   NaN

# %%
df.isnull().sum()
# Out:
# movies         0
# year         644
# genre         80
# rating      1820
# one-line       0
# stars          0
# votes       1820
# runtime     2958
# gross       9539
# dtype: int64

# %%
df["year"].value_counts()
# Out:
# 2020             1531
# 2019             1093
# 2021             1072
# 2018              751
# 2017              535
#                  ...
# 20082020            1
# 20082010            1
# 20152020            1
# 19922014            1
# 2018VideoGame       1
# Name: year, Length: 395, dtype: int64

# %%
df.tail(4)
# Out:
#                   MOVIES      YEAR  \
# 9995              Arcane  (2021– )
# 9996   Heart of Invictus  (2022– )
# 9997      The Imperfects  (2021– )
# 9998      The Imperfects  (2021– )
#
#                                            GENRE  RATING        ONE-LINE  \
# 9995  \nAnimation, Action, Adventure                 NaN  \nAdd a Plot\n
# 9996            \nDocumentary, Sport                 NaN  \nAdd a Plot\n
# 9997     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
# 9998     \nAdventure, Drama, Fantasy                 NaN  \nAdd a Plot\n
#
#                                                   STARS VOTES  RunTime Gross
# 9995                                                 \n   NaN      NaN   NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...   NaN      NaN   NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...   NaN      NaN   NaN
# 9998  \n    Director:\nJovanka Vuckovic\n| \n    Sta...   NaN      NaN   NaN

# %%
df["year"].isnull().sum()
# Out:
# 644

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (460, 9)

# %%
df =df.drop(columns=['one-line', 'stars'])
# Out:
#                     movies  year                                   genre  \
# 77  The Hitman's Bodyguard  2017       Action, Comedy, Crime
# 85           Jurassic Park  1993   Action, Adventure, Sci-Fi
#
#     rating    votes  runtime     gross
# 77     6.9  205,979    118.0   $75.47M
# 85     8.1  897,444    127.0  $402.45M

# %%
(df["rating"]>7).value_counts()
# Out:
# False    294
# True     166
# Name: rating, dtype: int64

# %%
df  = df.rename(columns={"movies":"movies_name"})
df = df.rename(columns={"movies_name":"movies"})

# %%
df.head(3)
# Out:
#    level_0  index                  movies  year  \
# 0        0     77  The Hitman's Bodyguard  2017
# 1        1     85           Jurassic Park  1993
# 2        2     95           Don't Breathe  2016
#
#                                     genre  rating    votes  runtime     gross
# 0       Action, Comedy, Crime                 6.9  205,979    118.0   $75.47M
# 1   Action, Adventure, Sci-Fi                 8.1  897,444    127.0  $402.45M
# 2     Crime, Horror, Thriller                 7.1  237,601     88.0   $89.22M

# %%
df = df.assign(Index=range(len(df))).set_index('Index')
df
# Out:
#        level_0  index                                             movies  \
# Index
# 0            0     77                             The Hitman's Bodyguard
# 1            1     85                                      Jurassic Park
# 2            2     95                                      Don't Breathe
# 3            3    111  The Lord of the Rings: The Fellowship of the Ring
# 4            4    125                                        Escape Room
# ...        ...    ...                                                ...
# 455        455   5750                           Vidal Sassoon: The Movie
# 456        456   5770                                       Men at Lunch
# 457        457   5835                                    Decoding Deepak
# 458        458   6056                                     Theo Who Lived
# 459        459   6292                                   Southern Justice
#
#            year                                     genre  rating      votes  \
# ...

# %%
df.head(10)
# Out:
#        level_0  index                                             movies  \
# Index
# 0            0     77                             The Hitman's Bodyguard
# 1            1     85                                      Jurassic Park
# 2            2     95                                      Don't Breathe
# 3            3    111  The Lord of the Rings: The Fellowship of the Ring
# 4            4    125                                        Escape Room
# 5            5    128                                               Jaws
# 6            6    132                                       The Departed
# 7            7    143                                          Gone Girl
# 8            8    144                     Jumanji: Welcome to the Jungle
# 9            9    145                                    American Psycho
#
#            year                                   genre  rating      votes  \
# Index
# ...
