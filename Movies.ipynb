# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies = pd.read_csv("/content/movies.csv")
df = movies.copy()

# %%
df.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
df.columns = [i.lower() for i in df]

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9568 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movies    9568 non-null   object
#  1   year      9026 non-null   object
#  2   genre     9490 non-null   object
#  3   rating    8168 non-null   float64
#  4   one-line  9568 non-null   object
#  5   stars     9568 non-null   object
#  6   votes     8168 non-null   object
#  7   runtime   7008 non-null   float64
#  8   gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 747.5+ KB

# %%
df["votes"]= df["votes"].str.replace(",","")

# %%
df.head()
# Out:
#                                 movies         year  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         genre  rating  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             one-line  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
df.isnull().sum().value_counts(ascending=False)
# Out:
# 0       3
# 1400    2
# 542     1
# 78      1
# 2560    1
# 9108    1
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# movies         0
# year         542
# genre         78
# rating      1400
# one-line       0
# stars          0
# votes       1400
# runtime     2560
# gross       9108
# dtype: int64

# %%
df.shape
# Out:
# (9568, 9)

# %%
d = df.isnull().any()

# %%
d.index
# Out:
# Index(['movies', 'year', 'genre', 'rating', 'one-line', 'stars', 'votes',
#        'runtime', 'gross'],
#       dtype='object')

# %%
df.isnull().all(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9993    False
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Length: 9568, dtype: bool

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2)
# Out:
# gross       95.19
# runtime     26.76
# rating      14.63
# votes       14.63
# year         5.66
# genre        0.82
# movies       0.00
# one-line     0.00
# stars        0.00
# dtype: float64

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2).head(1)
# Out:
# gross    95.19
# dtype: float64

# %%
col=round(df.isnull().sum().sort_values(ascending=False)/len(df)*100).head(1).index.values

# %%
df =df.drop(columns=col)

# %%
df.head()
# Out:
#                                 movies         year  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         genre  rating  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             one-line  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2)
# Out:
# runtime     26.76
# rating      14.63
# votes       14.63
# year         5.66
# genre        0.82
# movies       0.00
# one-line     0.00
# stars        0.00
# dtype: float64

# %%
df =df[df["runtime"].notnull()]

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2)
# Out:
# rating      3.17
# votes       3.17
# year        0.30
# genre       0.13
# movies      0.00
# one-line    0.00
# stars       0.00
# runtime     0.00
# dtype: float64

# %%
df.head()
# Out:
#                                 movies         year  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 5                          Outer Banks     (2020– )
#
#                                         genre  rating  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 5          \nAction, Crime, Drama                 7.6
#
#                                             one-line  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
df["runtime"]=df["runtime"].astype(float).astype(int)

# %%
df.head()
# Out:
#                                 movies         year  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 5                          Outer Banks     (2020– )
#
#                                         genre  rating  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 5          \nAction, Crime, Drama                 7.6
#
#                                             one-line  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
df.index = np.arange(1,len(df)+1)

# %%
df.shape
# Out:
# (7008, 8)

# %%
df.describe(include="all")
# Out:
#                   movies    year                 genre       rating  \
# count               7008    6987                  6999  6786.000000
# unique              5315     409                   478          NaN
# top      Bleach: Burîchi  (2020)  \nComedy                      NaN
# freq                  65     545                   595          NaN
# mean                 NaN     NaN                   NaN     6.861450
# std                  NaN     NaN                   NaN     1.245349
# min                  NaN     NaN                   NaN     1.100000
# 25%                  NaN     NaN                   NaN     6.100000
# 50%                  NaN     NaN                   NaN     7.000000
# 75%                  NaN     NaN                   NaN     7.700000
# max                  NaN     NaN                   NaN     9.900000
#
#               one-line stars votes      runtime
# count             7008  7008  6786  7008.000000
# unique            6817  6129  4043          NaN
# ...

# %%
df.describe()
# Out:
#             rating      runtime
# count  6786.000000  7008.000000
# mean      6.861450    68.874144
# std       1.245349    47.278890
# min       1.100000     1.000000
# 25%       6.100000    37.000000
# 50%       7.000000    60.000000
# 75%       7.700000    95.000000
# max       9.900000   853.000000

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2)
# Out:
# rating      3.17
# votes       3.17
# year        0.30
# genre       0.13
# movies      0.00
# one-line    0.00
# stars       0.00
# runtime     0.00
# dtype: float64

# %%
df["rating"].astype("category").value_counts()
# Out:
# 7.2    256
# 7.6    244
# 7.5    240
# 7.1    238
# 7.3    237
#       ...
# 1.8      1
# 2.4      1
# 2.2      1
# 2.0      1
# 1.1      1
# Name: rating, Length: 82, dtype: int64

# %%
df.loc[:,"rating"].fillna(df["rating"].mean(),inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# votes       222
# year         21
# genre         9
# movies        0
# rating        0
# one-line      0
# stars         0
# runtime       0
# dtype: int64

# %%
df=df[df["votes"].notnull()]

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2)
# Out:
# genre       0.1
# movies      0.0
# year        0.0
# rating      0.0
# one-line    0.0
# stars       0.0
# votes       0.0
# runtime     0.0
# dtype: float64

# %%
df["genre"]=df["genre"].notnull()

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2)
# Out:
# movies      0.0
# year        0.0
# genre       0.0
# rating      0.0
# one-line    0.0
# stars       0.0
# votes       0.0
# runtime     0.0
# dtype: float64

# %%
df.rename(columns={"one-line":"oneline"},inplace=True)

# %%
df.head()
# Out:
#                                 movies         year  genre  rating  \
# 1                        Blood Red Sky       (2021)   True     6.1
# 2  Masters of the Universe: Revelation     (2021– )   True     5.0
# 3                     The Walking Dead  (2010–2022)   True     8.2
# 4                       Rick and Morty     (2013– )   True     9.2
# 5                          Outer Banks     (2020– )   True     7.6
#
#                                              oneline  \
# 1  \nA woman with a mysterious illness is forced ...
# 2  \nThe war for Eternia begins again in what may...
# 3  \nSheriff Deputy Rick Grimes wakes up from a c...
# 4  \nAn animated series that follows the exploits...
# 5  \nA group of teenagers from the wrong side of ...
#
#                                                stars   votes  runtime
# 1  \n    Director:\nPeter Thorwarth\n| \n    Star...   21062      121
# 2  \n            \n    Stars:\nChris Wood, \nSara...   17870       25
# ...

# %%
len(df)/len(movies)*100
# Out:
# 67.86678667866786

# %%
df.shape
# Out:
# (6786, 8)

# %%
df = df.replace(r"\n","",regex=True)

# %%
df.head()
# Out:
#                                 movies         year  genre  rating  \
# 1                        Blood Red Sky       (2021)   True     6.1
# 2  Masters of the Universe: Revelation     (2021– )   True     5.0
# 3                     The Walking Dead  (2010–2022)   True     8.2
# 4                       Rick and Morty     (2013– )   True     9.2
# 5                          Outer Banks     (2020– )   True     7.6
#
#                                              oneline  \
# 1  A woman with a mysterious illness is forced in...
# 2  The war for Eternia begins again in what may b...
# 3  Sheriff Deputy Rick Grimes wakes up from a com...
# 4  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                stars   votes  runtime
# 1      Director:Peter Thorwarth|     Stars:Peri B...   21062      121
# 2                  Stars:Chris Wood, Sarah Michel...   17870       25
# ...

# %%
df["year"]=df["year"].str.extract(r'\b(\d{4})\b')

# %%
df.head()
# Out:
#                                 movies  year  genre  rating  \
# 1                        Blood Red Sky  2021   True     6.1
# 2  Masters of the Universe: Revelation  2021   True     5.0
# 3                     The Walking Dead  2010   True     8.2
# 4                       Rick and Morty  2013   True     9.2
# 5                          Outer Banks  2020   True     7.6
#
#                                              oneline  \
# 1  A woman with a mysterious illness is forced in...
# 2  The war for Eternia begins again in what may b...
# 3  Sheriff Deputy Rick Grimes wakes up from a com...
# 4  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                stars   votes  runtime
# 1      Director:Peter Thorwarth|     Stars:Peri B...   21062      121
# 2                  Stars:Chris Wood, Sarah Michel...   17870       25
# 3                  Stars:Andrew Lincoln, Norman R...  885805       44
# ...

# %%
df["year"]=pd.to_datetime(df["year"])

# %%
df["year"].astype(int)
# Out:
# 1       2021
# 2       2021
# 3       2010
# 4       2013
# 5       2020
#         ...
# 7003    2021
# 7004    2021
# 7005    2021
# 7006    2021
# 7007    2017
# Name: year, Length: 6786, dtype: int64

# %%
df.head()
# Out:
#                                 movies  year  genre  rating  \
# 1                        Blood Red Sky  2021   True     6.1
# 2  Masters of the Universe: Revelation  2021   True     5.0
# 3                     The Walking Dead  2010   True     8.2
# 4                       Rick and Morty  2013   True     9.2
# 5                          Outer Banks  2020   True     7.6
#
#                                              oneline  \
# 1  A woman with a mysterious illness is forced in...
# 2  The war for Eternia begins again in what may b...
# 3  Sheriff Deputy Rick Grimes wakes up from a com...
# 4  An animated series that follows the exploits o...
# 5  A group of teenagers from the wrong side of th...
#
#                                                stars   votes  runtime
# 1      Director:Peter Thorwarth|     Stars:Peri B...   21062      121
# 2                  Stars:Chris Wood, Sarah Michel...   17870       25
# 3                  Stars:Andrew Lincoln, Norman R...  885805       44
# ...
